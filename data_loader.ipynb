# %% [markdown]
# ### Document Loading

# %%
import os
from langchain_community.document_loaders import DirectoryLoader, TextLoader

directory_path = "./arch-wiki/html/en/"

if not os.path.exists(directory_path):
    print(f"Directory not found: {directory_path}")
else:
    loader = DirectoryLoader(
        path=directory_path,
        glob="**/*.html", # all html files and subdirectories
        loader_cls=TextLoader, # keeps html tags for document splitting
        show_progress=True
    )

docs = loader.load() # compare it to lazy load
# Out:
# 100%|██████████████████████████████████████████████████████████████████████▉| 2491/2493 [00:00<00:00, 8595.14it/s]

# %%
len(docs)
# Out:
# 2491

# %% [markdown]
# ### Document Splitting

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, HTMLHeaderTextSplitter

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

# initilaize header splitter
html_header_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# initilaize text splitter to ensure chunks fit in local llm
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    separators=["\n\n", "\n", " ", ""]
)

final_chunks=[]

for doc in docs:
    # if html file, split by header, then split again into smaller chunks
    if doc.metadata.get("source", "").endswith(".html"):
        header_splits = html_header_splitter.split_text(doc.page_content)

        # IMPORTANT: Manually carry over the 'source' from the original file
        for split in header_splits:
            split.metadata["source"] = doc.metadata.get("source")

        # DEBUG
        print(f"Found {len(header_splits)} header sections.")
        if len(header_splits) > 0:
            print(f"Metadata of first section: {header_splits[0].metadata}")

        
        final_chunks.extend(text_splitter.split_documents(header_splits))
    else:
        # non-html, use recursive splitter directly
        final_chunks.extend(text_splitter.split_documents([doc]))
# Out:
# Found 63 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/WireGuard.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sugar.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Character_encoding.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Hardware_detection_and_troubleshooting.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Intel_Quartus_Prime.html'}
# Found 46 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dhcpcd.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Guitarix.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bluetooth_mouse.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Command-line_shell.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Init.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Node.js.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:English.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/LinuxSampler.html'}
# Found 40 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/VirtualGL.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Fail2ban.html'}
# Found 48 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/LXDE.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Terminal_emulators.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Maple.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_13_(9340).html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Configuration_files.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Envy24control.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-integrity.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_Spectre_x360_13-w023dx.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Readline.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dnscrypt-proxy.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pkgsrc.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_P43s.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Telephony.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Greenclip.html'}
# Found 40 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Active_Directory_integration.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Acer_Nitro_AN515-43.html'}
# Found 74 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bumblebee.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Touchegg.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Web.html'}
# Found 74 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Compiz.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Framework_Laptop_16.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tillitis_TKey.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sound_system.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Arch_package_guidelines.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Peer-to-peer.html'}
# Found 49 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Convert_any_Movie_to_DVD_Video.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_Edge_E455.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Cwm.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Protocols.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/FluidSynth.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Multiboot_USB_drive.html'}
# Found 78 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mutt.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Fdisk.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sdcv.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Uzbl.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Electron.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Bluetooth.html'}
# Found 61 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Netctl.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/XDG_Autostart.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Console_applications.html'}
# Found 78 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RAID.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Hpfall.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_IdeaPad_Flex_10.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Twister.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NTFS.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Open_Database_Connectivity.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/One_Time_PassWord.html'}
# Found 37 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/IBus.html'}
# Found 49 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Deluge.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Trusted_Platform_Module.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASCII_art.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Extreme_(Gen_4i).html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/X_resources.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Slime.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Graphviz.html'}
# Found 60 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Podman.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Mechrevo.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MSI_GS66_11UX.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Vault.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_S440.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_P70.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_UX330UA.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Print.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/VCS_package_guidelines.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GEDA.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_IdeaPad_Flex_5_13IML05_Chromebook.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Boot_loaders.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Hiawatha.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Framework_Desktop.html'}
# Found 54 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Virtual_user_mail_system_with_Postfix,_Dovecot_and_Roundcube.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_13_2-in-1_(9315).html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Audiobook.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Input_Japanese_using_ibus.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacserve.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_IdeaPad_7_14are05.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Cairo-Dock.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Email_clients.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PyLoad.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pam_oath.html'}
# Found 53 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kerberos.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/DSDT.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_Edge_13.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ppp.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ArchWiki:Statistics.html'}
# Found 80 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Android.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pkgfile.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Distrobox.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X220.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_Inspiron_7586.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ente_server.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kernel_live_patching.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/TOMOYO_Linux.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pam_abl.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xiaomi_RedmiBook_Pro_15_2023.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Eee_PC_T101MT.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Openfire.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Son_of_Grid_Engine.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Chuwi_MiniBook_X_(2023).html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sysctl.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_ENVY_TouchSmart_17-j113tx.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_Edge_E330.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_Yoga_370.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Orthanc.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Red_Hat.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xiaomi_RedmiBook_Pro_16_2025.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Anki.html'}
# Found 84 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gamepad.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/FAT.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Samsung_ATIV_Book_9_Lite_NP905S3G-K02.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sieve_filters.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Package_manager.html'}
# Found 34 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pulse_Connect_Secure.html'}
# Found 74 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Advanced_Linux_Sound_Architecture.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Logwatch.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Newsraft.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Yakuake.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Qnix_QX2710.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Package_management.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MPRIS.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Issue_tracking_systems.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Luakit.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Desktop_environments.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Logitech_Marble_Mouse.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Relational_DBMSs.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Pages_flagged_with_Template:Archive.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X390_Yoga.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RemoteBox.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Midnight_Commander.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_Q408UG.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Certbot.html'}
# Found 76 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/R.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Taskd.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_15_(7590).html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Activating_numlock_on_bootup.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Yoga_(Gen_7).html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_Latitude_7490.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenShift.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Install_Arch_Linux_with_accessibility_options.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gmrun.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Install_Arch_Linux_on_ZFS.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/IMWheel.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Blueman.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rebuilderd.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Proxy_server.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sxiv.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sleep.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Domain_name_resolution.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Firewalld.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14_(AMD)_Gen_5.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_P15_Gen_1.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xpra.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Man_page.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Scala.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Carbon.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kbuilder.html'}
# Found 44 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Nix.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/d21d97e416f0b6a1fc6ac0b7157eec49.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_Inspiron_N5010.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Hypervisors.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Folding@home.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NoMachine.html'}
# Found 48 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/SSH_keys.html'}
# Found 121 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GnuPG.html'}
# Found 97 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sway.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_17_(9710).html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_UX303.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Software_projects.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lean_Theorem_Prover.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Download_utilities.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14_(AMD)_Gen_4.html'}
# Found 91 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kodi.html'}
# Found 95 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PDF,_PS_and_DjVu.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Intel_QC71.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tmuxp.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Steam_Input_Configurator.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_Stream_14-cb0XX.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kanshi.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_P1_(Gen_4).html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dynamic_DNS.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GPD_Pocket_3.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Creating_packages_for_other_distributions.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mumble.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Realtime_process_management.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PhpLDAPadmin.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Help:Laptop_page_guidelines.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_Envy_x360_15-bq102ng.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Manim.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ProFTPD.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Puppet_server.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/JHBuild.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Carbon_(Gen_9).html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Extreme.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Metasploit_Framework.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Solo.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Perl_package_guidelines.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Himitsu.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Parental_control.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/DNS-over-HTTPS.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_Inspiron_15_(7590).html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/System76_Galago_Pro_galp3.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_E14_Gen_2_(AMD).html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Logging.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Software.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:39e49758728721f5a0714da6d3799ffa.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Pages_or_sections_flagged_with_Template:Expansion.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_UM3402YAR.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/SSMTP.html'}
# Found 91 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenSSH.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Fujitsu_Lifebook_U9311.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Acer_Predator_Helios_300.html'}
# Found 57 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Firejail.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MinIO.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Talkd_and_the_talk_command.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/LG_Gram_14_2022.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gitfs.html'}
# Found 86 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/System76_Oryx_Pro.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:HASEE.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/X10.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Authelia.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Office.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:IOS.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Toshiba_Satellite_L300.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/WebGrab+Plus.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RVM.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Acer_Chromebook_11_(C732).html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gajim.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sftpman.html'}
# Found 54 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Steam_Deck.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kea.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PyPy.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_TX201LA.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Festival.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Snap.html'}
# Found 37 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Pages_or_sections_flagged_with_Template:Move.html'}
# Found 84 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Wine.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OwnTone.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ERPNext.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rofi.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_E14_Gen_3_(AMD).html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_Inspiron_5415.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenDKIM.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenDMARC.html'}
# Found 45 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Unreal_Engine_5.html'}
# Found 75 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Hyprland.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Extreme_(Gen_5).html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Romanian_eID.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Pages_using_invalid_self-closed_HTML_tags.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Hardware_raytracing.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Cozy.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkBook_14s_Yoga_ITL.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacat.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Stress_testing.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ada.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Getmail.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Unified_kernel_image.html'}
# Found 52 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Desktop_entries.html'}
# Found 64 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Jans.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_ZBook_Studio_G5.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/USB_storage_devices.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Official_repositories_web_interface.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sandbox.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Remmina.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xinit.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Speech_dispatcher.html'}
# Found 40 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Cursor_themes.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tcplay.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Cloud-init.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Foremost.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_E402S.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Input_devices.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X230.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Transmission.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Chuncord.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_N550JV.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T400.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tmpfs.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mailnag.html'}
# Found 60 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_13_(9350).html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenFOAM.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Internet_Relay_Chat.html'}
# Found 62 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/IPv6.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_ProBook_435_G7.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/XDG_MIME_Applications.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/BackupPC.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:76051c09d8ff3414926cdd159809e72c.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Wine_package_guidelines.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/DKMS_package_guidelines.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rng-tools.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Display_managers.html'}
# Found 46 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GDM.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ArchWiki:Bots.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:MSI.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Phrik.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gitolite.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pianobar.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Arch_is_the_best.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MEncoder.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Labwc.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Virt-manager.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Fwupd.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Packaging_Brother_printer_drivers.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Search.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Makepkg-optimize.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Quod_Libet.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Intel_NUC.html'}
# Found 45 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Gaming.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ledger.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ext4.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Fsck.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/File_manager_functionality.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Web_browser.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ZoneMinder.html'}
# Found 55 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Picom.html'}
# Found 94 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Openbox.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Migrate_installation_to_new_hardware.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenSMTPD.html'}
# Found 40 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Window_Maker.html'}
# Found 73 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xfce.html'}
# Found 46 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/General_guidelines.html'}
# Found 61 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Sudo.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14s_(AMD)_Gen_1.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/HP_Laptop_14-fq0xxx.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bug_Day.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Software_comparisons.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Archive.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Security_testing.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Chuwi.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/KiwiIRC.html'}
# Found 48 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Private_Internet_Access.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Amateur_radio.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Hadoop.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Autofs.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tp-battery-mode.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ktorrent.html'}
# Found 41 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Apache_HTTP_Server.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenDJ.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xprofile.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ly.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/LLVM.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Python_package_guidelines.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Acer_Chromebook_14_CB3-431_(Edgar).html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Teams.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Simple_Orca_Plugin_System.html'}
# Found 42 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dd.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/7-Zip.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Samsung.html'}
# Found 44 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xmodmap.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MAC_address_spoofing.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mozc.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Help:I18n.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Instant_messaging.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Password_managers.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Postorius.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Distributed_computing.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Paperkey.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sound.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:XMPP.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Concurrent_Versions_System.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/CouchDB.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xcompmgr.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Extended_attributes.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Arch_build_system.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Trinity.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/I2C.html'}
# Found 46 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Webcam_setup.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Synchronization.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Acer_Switch_Alpha_12.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Nyxt.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:GNU.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_W520.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Git_server.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Tectonic.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Git_web_interfaces.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Open_Broadcaster_Software.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kernel.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Notion.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_Edge_E430.html'}
# Found 53 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pidgin.html'}
# Found 34 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Spectrwm.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sony.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/System76_Darter_Pro_6.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Zoom_Meetings.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Arch_projects.html'}
# Found 49 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Syslog-ng.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kerbal_Space_Program.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Shairport_Sync.html'}
# Found 146 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/KDE.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RTL-SDR.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Common_Desktop_Environment.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_Yoga_Pro_7_14AHP9.html'}
# Found 51 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/XFS.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rsyslog.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Logitech_G300.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Partclone.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Servers.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Wake-on-LAN.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Iptv.org_EPG_Grabber.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Alienware_15.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rsnapshot.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Gcin.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mathematica.html'}
# Found 55 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Backlight.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Launchpad_MSP430G2.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_MeMO_Pad_7_(ME176C(X)).html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Snort.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PowerDNS.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Carbon_(Gen_4).html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ratpoison.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Intel_NUC_X15.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_13_(9305).html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Help.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Google.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Pages_or_sections_flagged_with_Template:Accuracy.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Perl_Policy.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ocrdesktop.html'}
# Found 72 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Numerical_analysis.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Mobile_devices.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/FUSE.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kernel_parameters.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RecordMyDesktop.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Compositor.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Virtual_Private_Network.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X201_Tablet.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Help:Template.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Silent_boot.html'}
# Found 50 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/X11vnc.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xiaomi_Mi_Notebook_Air_13.3.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Access_Control_Lists.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_X1_Carbon_(Gen_2).html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Main_page_(Qhichwa).html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rdesktop.html'}
# Found 55 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bash.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNU_Compiler_Collection.html'}
# Found 39 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/MacBookPro8,x.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Comparison_of_desktop_environments.html'}
# Found 28 header sections.
# ...
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/USB/IP.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Minecraft/Java_Edition_server.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Vim/YouCompleteMe.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_UX430/UX530.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/LIRC/Quick_start_guide.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Document_viewer.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Flashback.html'}
# Found 77 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Troubleshooting.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Files.html'}
# Found 58 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Keyring.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Web.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Gedit.html'}
# Found 79 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Tips_and_tricks.html'}
# Found 40 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GNOME/Evolution.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman/Pacnew_and_Pacsave.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman/Package_signing.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman/Rosetta.html'}
# Found 68 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman/Tips_and_tricks.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Pacman/Restore_local_database.html'}
# Found 32 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Solid_state_drive/NVMe.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Solid_state_drive/Memory_cell_clearing.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Apache_HTTP_Server/mod_perl.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Apache_HTTP_Server/mod_fcgid.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Apache_HTTP_Server/mod_gnutls.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Apache_HTTP_Server/mod_wsgi.html'}
# Found 41 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Arch_package_guidelines/Security.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ISCSI/Boot.html'}
# Found 13 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ISCSI/LIO.html'}
# Found 38 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Chrome_OS_devices/Crostini.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Chrome_OS_devices/Custom_firmware.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Chrome_OS_devices/Chromebook.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Font_configuration/Chinese.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Font_configuration/Examples.html'}
# Found 55 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Advanced_Linux_Sound_Architecture/Troubleshooting.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Advanced_Linux_Sound_Architecture/Configuration_examples.html'}
# Found 34 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bash/Prompt_customization.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bash/Functions.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/RTorrent/RuTorrent.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Systemd/User.html'}
# Found 26 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Systemd/Journal.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Systemd/Sandboxing.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Systemd/Timers.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Systemd/FAQ.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Unified_Extensible_Firmware_Interface/Secure_Boot.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Sony.html'}
# Found 7 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Toshiba.html'}
# Found 41 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/HP.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Samsung.html'}
# Found 61 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Lenovo.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Framework.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Apple.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Acer.html'}
# Found 45 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Other.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/Dell.html'}
# Found 14 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/MSI.html'}
# Found 33 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Laptop/ASUS.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Python/Virtual_environment.html'}
# Found 66 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/SANE/Scanner-specific_problems.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PHP/pthreads_extension.html'}
# Found 47 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/VMware/Install_Arch_Linux_as_a_guest.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sandbox/A.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sandbox/AAA.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sandbox/AA.html'}
# Found 5 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Category:Sandbox/AB.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kernel/Arch_build_system.html'}
# Found 34 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Kernel/Traditional_compilation.html'}
# Found 31 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Samba/Active_Directory_domain_controller.html'}
# Found 16 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ZTE_MF626_/_MF636.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Linux_Containers/Using_VPNs.html'}
# Found 80 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Network_configuration/Wireless.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Network_configuration/Ethernet.html'}
# Found 51 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/QEMU/Troubleshooting.html'}
# Found 23 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/QEMU/Guest_graphics_acceleration.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/QEMU/Advanced_networking.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/TeX_Live/CJK.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/TeX_Live/FAQ.html'}
# Found 58 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mac/Troubleshooting.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Improving_performance/Boot_process.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Bubblewrap/Examples.html'}
# Found 78 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Firefox/Tweaks.html'}
# Found 58 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Firefox/Privacy.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Firefox/Profile_on_RAM.html'}
# Found 44 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Rxvt-unicode/Tips_and_tricks.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Binfmt_misc_for_Java/Wrapper_examples.html'}
# Found 24 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Music_Player_Daemon/Troubleshooting.html'}
# Found 58 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Music_Player_Daemon/Tips_and_tricks.html'}
# Found 30 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dell_XPS_M1330_/_M1530.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Linux_console/Keyboard_configuration.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Mkinitcpio/Minimal_initramfs.html'}
# Found 144 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Utilities.html'}
# Found 91 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Documents.html'}
# Found 114 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Multimedia.html'}
# Found 94 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Science.html'}
# Found 34 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Security.html'}
# Found 91 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Internet.html'}
# Found 94 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/List_of_applications/Other.html'}
# Found 20 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14/T14s_(Intel)_Gen_4.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14/T14s_(Intel)_Gen_1.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14/T14s_(Intel)_Gen_5.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14/T14s_(Intel)_Gen_3.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Lenovo_ThinkPad_T14/T14s_(Intel)_Gen_2.html'}
# Found 9 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NFS/Kerberos.html'}
# Found 68 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NFS/Troubleshooting.html'}
# Found 36 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GIMP/CMYK_support.html'}
# Found 18 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ZTE_MF110/MF190.html'}
# Found 28 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Openswan_L2TP/IPsec_VPN_client_setup.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Drive_preparation.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Mounting_at_login.html'}
# Found 57 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Specialties.html'}
# Found 111 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Encrypting_an_entire_system.html'}
# Found 52 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Device_encryption.html'}
# Found 17 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Encrypting_a_non-root_file_system.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/Swap_encryption.html'}
# Found 19 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Dm-crypt/System_configuration.html'}
# Found 44 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GRUB/EFI_examples.html'}
# Found 67 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/GRUB/Tips_and_tricks.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Securely_wipe_disk/Tips_and_tricks.html'}
# Found 80 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NVIDIA/Troubleshooting.html'}
# Found 51 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NVIDIA/Tips_and_tricks.html'}
# Found 44 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/VirtualBox/Install_Arch_Linux_as_a_guest.html'}
# Found 21 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Debugging/Getting_traces.html'}
# Found 11 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Debugging/Profiling.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Reproducible_builds/Status.html'}
# Found 74 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PCI_passthrough_via_OVMF/Examples.html'}
# Found 35 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Conky/Tips_and_tricks.html'}
# Found 25 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Power_management/Wakeup_triggers.html'}
# Found 62 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Power_management/Suspend_and_hibernate.html'}
# Found 46 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Xorg/Keyboard_configuration.html'}
# Found 10 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/PipeWire/Examples.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Ppp/Mobile_broadband_modem.html'}
# Found 43 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ZFS/Virtual_disks.html'}
# Found 66 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/CUPS/Printer-specific_problems.html'}
# Found 98 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/CUPS/Troubleshooting.html'}
# Found 29 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/CUPS/Printer_sharing.html'}
# Found 12 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/NetworkManager/Privacy.html'}
# Found 22 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenVPN/Bridge.html'}
# Found 15 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/OpenVPN/Checklist_guide.html'}
# Found 27 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/ASUS_Zenbook_UX333/433/533.html'}
# Found 1 header sections.
# Metadata of first section: {'source': 'arch-wiki/html/en/Font_configuration/Examples/No_anti-aliasing.html'}

# %%
len(final_chunks)
# Out:
# 75185
